# %% [markdown]
# # **WEEK10**

# %% [markdown]
# **AIM:** Face Detection using Haar Cascades for eyes and face

# %%
# Program for Face and Eyes detection using Haarcascade classifier:
import numpy as np
import cv2
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

img = cv2.imread("elon2.jpg")
gray = cv2.imread('/content/elon2.jpg',0)

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    image = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w];
    roi_color = img[y:y+h, x:x+w];
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x1060 at 0x7F410B59E110>

# %% [markdown]
# **AIM:** Detection using sift algorithm

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from google.colab.patches import cv2_imshow

img1 = cv2.imread('/content/elon1.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

#keypoints
sift = cv2.SIFT_create()
keypoints_1, descriptors_1 = sift.detectAndCompute(gray1,None)

img_1 = cv2.drawKeypoints(gray1,keypoints_1,gray1) 
plt.imshow(img_1)

# %% [markdown]
# **AIM:** Plot images using matplotloib and convert them into grey images

# %%
img2 = cv2.imread('elon2.jpg') 
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

figure, ax = plt.subplots(1, 2, figsize=(16, 8))

ax[0].imshow(img1, cmap='gray')
ax[1].imshow(img2, cmap='gray')

# %% [markdown]
# **AIM: ** Comapring two faces in differrent images using cv2

# %%
surf = cv2.xfeatures2d.SIFT_create()

keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)
keypoints_2, descriptors_2 = sift.detectAndCompute(img2,None)

len(keypoints_1), len(keypoints_2)

#feature matching
bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches[:50], img2, flags=2)
plt.imshow(img3)
plt.show()

# %% [markdown]
# **Inference:**  Learned how to use opencv for Haar Cascade and Sift algorithims as there are inbuilt in opencv module which we will directly import does the operations
# Applications:
# It can process images and videos to identify objects, faces, or even handwriting of a human better then other modules .
# What we have done in this Week is
# * Sorting images by mapping/comapring two images
# * Converting images into Greyscale and plotting them like graphs based on axis
# * Decting Eyes and Face using opencv model for a static image using haarcascade values which are stores in xml format.
